# %% [markdown]
# задание 1

# %%
string = ('Спустя %(years)d 2 лет они смогли расшифровать это %(text)s' %{'years': 20, 'text': 'послание'})
print (string)
# Out:
# Спустя 20 лет они смогли расшифровать это послание

# %% [markdown]
# задание 2

# %%
str = input() 
print((str+'')*5)
# Out:
# Go
# Go Go Go Go Go

# %% [markdown]
# задание 3

# %%
inp_str = "да выпей же чаю!" 
inp_str[6:11:4]
# Out:
# 'ее'

# %% [markdown]
# задание 4

# %%
my_set = set([1, 2, 2, 3, 3, 4, 4]) 
print(my_set)
# Out:
# {1, 2, 3, 4}
